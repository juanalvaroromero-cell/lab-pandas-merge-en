# %%
import numpy as np
import pandas as pd   
from IPython.display import display_html

# %% [markdown]
# # Introduction
#
# In this lab we want you to learn and investigate some concepts in the context of Pandas: **concatenating**, **joining**, and **merging**. We want to review these concepts because it will make the subsequent work in transforming the datasets a lot more efficient.

# %% [markdown]
# # Concatenating, Joining, & Merging Tutorial
#
#
# ## Concatenating
#
# Concatenating two dataframes combines two dataframes so that we append the rows of one dataframe at the end of the other. Our column names have to be identical for this function to work properly.
#
# Below is an example of the `concat()` function in pandas

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.concat.html

# %%
df1 = pd.DataFrame({'A': ['a'+str(x) for x in range(3)],
                    'B': ['b'+str(x) for x in range(3)],
                    'C': ['c'+str(x) for x in range(3)]},
                     index=[0, 1, 2])

df2 = pd.DataFrame({'A': ['a'+str(x) for x in range(3, 6)],
                    'B': ['b'+str(x) for x in range(3, 6)],
                    'C': ['c'+str(x) for x in range(3, 6)]},
                     index=[3, 4, 5]) 

df3 = pd.DataFrame({'D': ['d'+str(x) for x in range(3)],
                    'E': ['e'+str(x) for x in range(3)],
                    'F': ['f'+str(x) for x in range(3)]},
                     index=[0, 1, 2]) 

df4 = pd.DataFrame({'D': ['d'+str(x) for x in range(3, 6)],
                    'E': ['e'+str(x) for x in range(3, 6)],
                    'F': ['f'+str(x) for x in range(3, 6)]},
                     index=[3, 4, 5]) 

print(df1, '\n---\n', df2, '\n---\n', df3, '\n---\n',df4)
# Out:
#     A   B   C
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# ---
#      A   B   C
# 3  a3  b3  c3
# 4  a4  b4  c4
# 5  a5  b5  c5
# ---
#      D   E   F
# 0  d0  e0  f0
# 1  d1  e1  f1
# 2  d2  e2  f2
# ---
#      D   E   F
# 3  d3  e3  f3
# 4  d4  e4  f4
# 5  d5  e5  f5

# %% [markdown]
# Let's try concatenating `df1` and `df2`, as well as `df3` and `df4`.

# %%
df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('df1')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('df2')
df3_styler = df3.style.set_table_attributes("style='display:inline'").set_caption('df3')
df4_styler = df4.style.set_table_attributes("style='display:inline'").set_caption('df4')

display_html(df1_styler._repr_html_() + " ||| " + df2_styler._repr_html_() + " ||| " + df3_styler._repr_html_() + " ||| " + df4_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_13f4a" style='display:inline'>
#   <caption>df1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13f4a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_13f4a_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_13f4a_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13f4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13f4a_row0_col0" class="data row0 col0" >a0</td>
#       <td id="T_13f4a_row0_col1" class="data row0 col1" >b0</td>
#       <td id="T_13f4a_row0_col2" class="data row0 col2" >c0</td>
#     </tr>
#     <tr>
#       <th id="T_13f4a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13f4a_row1_col0" class="data row1 col0" >a1</td>
#       <td id="T_13f4a_row1_col1" class="data row1 col1" >b1</td>
#       <td id="T_13f4a_row1_col2" class="data row1 col2" >c1</td>
#     </tr>
#     <tr>
#       <th id="T_13f4a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13f4a_row2_col0" class="data row2 col0" >a2</td>
#       <td id="T_13f4a_row2_col1" class="data row2 col1" >b2</td>
#       <td id="T_13f4a_row2_col2" class="data row2 col2" >c2</td>
#     </tr>
#   </tbody>
# </table>
#  ||| <style type="text/css">
# </style>
# <table id="T_e159e" style='display:inline'>
#   <caption>df2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e159e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e159e_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_e159e_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e159e_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_e159e_row0_col0" class="data row0 col0" >a3</td>
#       <td id="T_e159e_row0_col1" class="data row0 col1" >b3</td>
#       <td id="T_e159e_row0_col2" class="data row0 col2" >c3</td>
#     </tr>
#     <tr>
#       <th id="T_e159e_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_e159e_row1_col0" class="data row1 col0" >a4</td>
#       <td id="T_e159e_row1_col1" class="data row1 col1" >b4</td>
#       <td id="T_e159e_row1_col2" class="data row1 col2" >c4</td>
#     </tr>
#     <tr>
#       <th id="T_e159e_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_e159e_row2_col0" class="data row2 col0" >a5</td>
#       <td id="T_e159e_row2_col1" class="data row2 col1" >b5</td>
#       <td id="T_e159e_row2_col2" class="data row2 col2" >c5</td>
#     </tr>
#   </tbody>
# </table>
#  ||| <style type="text/css">
# </style>
# <table id="T_2e512" style='display:inline'>
#   <caption>df3</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e512_level0_col0" class="col_heading level0 col0" >D</th>
#       <th id="T_2e512_level0_col1" class="col_heading level0 col1" >E</th>
#       <th id="T_2e512_level0_col2" class="col_heading level0 col2" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e512_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e512_row0_col0" class="data row0 col0" >d0</td>
#       <td id="T_2e512_row0_col1" class="data row0 col1" >e0</td>
#       <td id="T_2e512_row0_col2" class="data row0 col2" >f0</td>
#     </tr>
#     <tr>
#       <th id="T_2e512_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e512_row1_col0" class="data row1 col0" >d1</td>
#       <td id="T_2e512_row1_col1" class="data row1 col1" >e1</td>
#       <td id="T_2e512_row1_col2" class="data row1 col2" >f1</td>
#     </tr>
#     <tr>
#       <th id="T_2e512_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e512_row2_col0" class="data row2 col0" >d2</td>
#       <td id="T_2e512_row2_col1" class="data row2 col1" >e2</td>
#       <td id="T_2e512_row2_col2" class="data row2 col2" >f2</td>
#     </tr>
#   </tbody>
# </table>
#  ||| <style type="text/css">
# </style>
# <table id="T_8e570" style='display:inline'>
#   <caption>df4</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e570_level0_col0" class="col_heading level0 col0" >D</th>
#       <th id="T_8e570_level0_col1" class="col_heading level0 col1" >E</th>
#       <th id="T_8e570_level0_col2" class="col_heading level0 col2" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e570_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_8e570_row0_col0" class="data row0 col0" >d3</td>
#       <td id="T_8e570_row0_col1" class="data row0 col1" >e3</td>
#       <td id="T_8e570_row0_col2" class="data row0 col2" >f3</td>
#     </tr>
#     <tr>
#       <th id="T_8e570_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_8e570_row1_col0" class="data row1 col0" >d4</td>
#       <td id="T_8e570_row1_col1" class="data row1 col1" >e4</td>
#       <td id="T_8e570_row1_col2" class="data row1 col2" >f4</td>
#     </tr>
#     <tr>
#       <th id="T_8e570_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_8e570_row2_col0" class="data row2 col0" >d5</td>
#       <td id="T_8e570_row2_col1" class="data row2 col1" >e5</td>
#       <td id="T_8e570_row2_col2" class="data row2 col2" >f5</td>
#     </tr>
#   </tbody>
# </table>

# %%
# your code here
## df1 concat d2
display(pd.concat([df1,df2], axis=0, keys=["df 1", "df 2"], sort=False))

## df3 concat d4
display(pd.concat([df3,df4], axis=0, keys=["df 3", "df 4"], sort=False))

##  `sort=False` param is supplied to silence a warning message on a future Pandas change
# Out:
#          A   B   C
# df 1 0  a0  b0  c0
#      1  a1  b1  c1
#      2  a2  b2  c2
# df 2 3  a3  b3  c3
#      4  a4  b4  c4
#      5  a5  b5  c5
#          D   E   F
# df 3 0  d0  e0  f0
#      1  d1  e1  f1
#      2  d2  e2  f2
# df 4 3  d3  e3  f3
#      4  d4  e4  f4
#      5  d5  e5  f5

# %% [markdown]
# From the output above, you see the second dataframe is appended at the bottom of the first dataframe.
#
# Now let's try concatenating `df1`, `df2`, `df3`, and `df4` all together.
#
# Note that the `sort=False` param is supplied to silence a warning message on a future Pandas change. It does not make any difference on the output.

# %%
# your code here
## df1 , df2 , df3 , df4 concat
display(pd.concat([df1,df2,df3,df4], axis=0, keys=["df 1", "df 2","df 3", "df 4"], sort=False))
# Out:
#           A    B    C    D    E    F
# df 1 0   a0   b0   c0  NaN  NaN  NaN
#      1   a1   b1   c1  NaN  NaN  NaN
#      2   a2   b2   c2  NaN  NaN  NaN
# df 2 3   a3   b3   c3  NaN  NaN  NaN
#      4   a4   b4   c4  NaN  NaN  NaN
#      5   a5   b5   c5  NaN  NaN  NaN
# df 3 0  NaN  NaN  NaN   d0   e0   f0
#      1  NaN  NaN  NaN   d1   e1   f1
#      2  NaN  NaN  NaN   d2   e2   f2
# df 4 3  NaN  NaN  NaN   d3   e3   f3
#      4  NaN  NaN  NaN   d4   e4   f4
#      5  NaN  NaN  NaN   d5   e5   f5

# %% [markdown]
# What do we find?
#
# * Pandas' `concat` method respects indexes of all axes.
#     * Because `df3` and `df4` have different column indexes than `df1` and `df2`, `concat` put them into different columns.
#     * `df3` and `df4` also retain their original row indexes of 0-5 instead of continuing from the last index of `df2`.
# * `concat` creates `NaN` at places where values are missing.
#
# Try also supplying `ignore_index=True` to `concat`. How is the output different?

# %%
# your code here

## df1 , df2 , df3 , df4 concat with "ignore_index=True"
display(pd.concat([df1,df2,df3,df4], axis=0, ignore_index=True, keys=["df 1", "df 2","df 3", "df 4"], sort=False))
# Out:
#       A    B    C    D    E    F
# 0    a0   b0   c0  NaN  NaN  NaN
# 1    a1   b1   c1  NaN  NaN  NaN
# 2    a2   b2   c2  NaN  NaN  NaN
# 3    a3   b3   c3  NaN  NaN  NaN
# 4    a4   b4   c4  NaN  NaN  NaN
# 5    a5   b5   c5  NaN  NaN  NaN
# 6   NaN  NaN  NaN   d0   e0   f0
# 7   NaN  NaN  NaN   d1   e1   f1
# 8   NaN  NaN  NaN   d2   e2   f2
# 9   NaN  NaN  NaN   d3   e3   f3
# 10  NaN  NaN  NaN   d4   e4   f4
# 11  NaN  NaN  NaN   d5   e5   f5

# %% [markdown]
# #### Explanation
# The difference when we use "ignore_index=True" is in index values , with the parameter the index column is 0 to n-1 and without the parameter respect the index of every row of every axe

# %% [markdown]
# ## Merging and Joining
#
# Pandas has two functions for joining datasets: `merge()` and `join()`. They perform the same task but have different options and syntax.
#
# Below is an example of `merge` and `join`.
# HINT (uses the column that repeats in both dataframes )

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %%
left = pd.DataFrame({'idx': ['i'+str(x) for x in range(3)],
                     'A': ['a'+str(x) for x in range(3)],
                     'B': ['b'+str(x) for x in range(3)]})


right = pd.DataFrame({'idx': ['i'+str(x) for x in range(1,4)],
                     'C': ['c'+str(x) for x in range(1,4)],
                     'D': ['d'+str(x) for x in range(1,4)]})

# %%
left
# Out:
#   idx   A   B
# 0  i0  a0  b0
# 1  i1  a1  b1
# 2  i2  a2  b2

# %%
right
# Out:
#   idx   C   D
# 0  i1  c1  d1
# 1  i2  c2  d2
# 2  i3  c3  d3

# %% [markdown]
# `join` is identical to `merge`. But when using join, we need to explicitly set the index column of the dataframes to join using `set_index`:

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html

# %%
# your code here
## join default
print("JOIN default type 'left'")
display(left.set_index("idx").join(right.set_index("idx"))) ## by default is 'left'
## join 'inner'
print("JOIN type 'inner'")
display(left.set_index("idx").join(right.set_index("idx"),how="inner")) ## selected 'inner'
## merge default
print("MERGE default type 'inner'")
display(pd.merge(left,right)) ## by default is 'inner'
## merge 'left''
print("MERGE type 'left'")
display(pd.merge(left,right,how='left'))## selected 'left'
# Out:
# JOIN default type 'left'
#       A   B    C    D
# idx
# i0   a0  b0  NaN  NaN
# i1   a1  b1   c1   d1
# i2   a2  b2   c2   d2
# JOIN type 'inner'
#       A   B   C   D
# idx
# i1   a1  b1  c1  d1
# i2   a2  b2  c2  d2
# MERGE default type 'inner'
#   idx   A   B   C   D
# 0  i1  a1  b1  c1  d1
# 1  i2  a2  b2  c2  d2
# MERGE type 'left'
#   idx   A   B    C    D
# 0  i0  a0  b0  NaN  NaN
# 1  i1  a1  b1   c1   d1
# 2  i2  a2  b2   c2   d2

# %% [markdown]
# And you see, `join` disregards the row of `right` with the unmatching index `i3`. It retains the row of `left` with the unmatching index `i0` but uses `NaN` for the missing data after joining.

# %% [markdown]
# #### There are other options we can explore with the `merge()` and `join()` functions.
#
# Specifically, we can specify `how`. This argument in the function tells us whether we are performing an inner, left, right, or outer join.
#
# We can also specify a different column for joining in the `merge()` function using the `left_on` and `right_on` arguments. Check out the following documentations if you want to explore more:
#
# [pandas.DataFrame.merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html)
#
# [pandas.DataFrame.join](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.join.html)

# %% [markdown]
# #### EXTRA Explanation
# join default = merge 'left' & merge default = join 'inner' . Only have a difference in de index column, JOIN respect de previously index column but MERGE put a new index column 0 to n-1

# %% [markdown]
# ## Bonus Question
#
# Now if you look back on `merge` and `join`, you realize that in order to perform these functions on a set of dataframes, these dataframes must share a common column as the index. Only rows that have the same index values will be joined. This is similar to the [`join` function in MySQL](https://www.w3schools.com/sql/sql_join.asp), isn't it?
#
# The bonus question for you is to figure out how to join and concatenate `df1`, `df2`, `df3`, and `df4` we created at the beginning of this challenge. Your end product should look like this:
#
# ![df1-2-3-4.png](../images/df1-2-3-4.png)

# %%
# your code here
display_html(df1_styler._repr_html_() + " ||| " + df2_styler._repr_html_() + " ||| " + df3_styler._repr_html_() + " ||| " + df4_styler._repr_html_(), raw=True)
df1_df3 = df1.join(df3) ## join df1 and df3
#display(df1_df3)
df2_df4 = df2.join(df4) ## join df2 and df4
#display(df2_df4)
df1_df2_df3_df4 = pd.concat([df1_df3, df2_df4], axis=0, sort=False) ## concat df1_df3 and df2_df4
display(df1_df2_df3_df4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_13f4a" style='display:inline'>
#   <caption>df1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13f4a_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_13f4a_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_13f4a_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13f4a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13f4a_row0_col0" class="data row0 col0" >a0</td>
#       <td id="T_13f4a_row0_col1" class="data row0 col1" >b0</td>
#       <td id="T_13f4a_row0_col2" class="data row0 col2" >c0</td>
#     </tr>
#     <tr>
#       <th id="T_13f4a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13f4a_row1_col0" class="data row1 col0" >a1</td>
#       <td id="T_13f4a_row1_col1" class="data row1 col1" >b1</td>
#       <td id="T_13f4a_row1_col2" class="data row1 col2" >c1</td>
#     </tr>
#     <tr>
#       <th id="T_13f4a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13f4a_row2_col0" class="data row2 col0" >a2</td>
#       <td id="T_13f4a_row2_col1" class="data row2 col1" >b2</td>
#       <td id="T_13f4a_row2_col2" class="data row2 col2" >c2</td>
#     </tr>
#   </tbody>
# </table>
#  ||| <style type="text/css">
# </style>
# <table id="T_e159e" style='display:inline'>
#   <caption>df2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e159e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_e159e_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_e159e_level0_col2" class="col_heading level0 col2" >C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e159e_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_e159e_row0_col0" class="data row0 col0" >a3</td>
#       <td id="T_e159e_row0_col1" class="data row0 col1" >b3</td>
#       <td id="T_e159e_row0_col2" class="data row0 col2" >c3</td>
#     </tr>
#     <tr>
#       <th id="T_e159e_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_e159e_row1_col0" class="data row1 col0" >a4</td>
#       <td id="T_e159e_row1_col1" class="data row1 col1" >b4</td>
#       <td id="T_e159e_row1_col2" class="data row1 col2" >c4</td>
#     </tr>
#     <tr>
#       <th id="T_e159e_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_e159e_row2_col0" class="data row2 col0" >a5</td>
#       <td id="T_e159e_row2_col1" class="data row2 col1" >b5</td>
#       <td id="T_e159e_row2_col2" class="data row2 col2" >c5</td>
#     </tr>
#   </tbody>
# </table>
#  ||| <style type="text/css">
# </style>
# <table id="T_2e512" style='display:inline'>
#   <caption>df3</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e512_level0_col0" class="col_heading level0 col0" >D</th>
#       <th id="T_2e512_level0_col1" class="col_heading level0 col1" >E</th>
#       <th id="T_2e512_level0_col2" class="col_heading level0 col2" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e512_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e512_row0_col0" class="data row0 col0" >d0</td>
#       <td id="T_2e512_row0_col1" class="data row0 col1" >e0</td>
#       <td id="T_2e512_row0_col2" class="data row0 col2" >f0</td>
#     </tr>
#     <tr>
#       <th id="T_2e512_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e512_row1_col0" class="data row1 col0" >d1</td>
#       <td id="T_2e512_row1_col1" class="data row1 col1" >e1</td>
#       <td id="T_2e512_row1_col2" class="data row1 col2" >f1</td>
#     </tr>
#     <tr>
#       <th id="T_2e512_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e512_row2_col0" class="data row2 col0" >d2</td>
#       <td id="T_2e512_row2_col1" class="data row2 col1" >e2</td>
#       <td id="T_2e512_row2_col2" class="data row2 col2" >f2</td>
#     </tr>
#   </tbody>
# </table>
#  ||| <style type="text/css">
# </style>
# <table id="T_8e570" style='display:inline'>
#   <caption>df4</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e570_level0_col0" class="col_heading level0 col0" >D</th>
#       <th id="T_8e570_level0_col1" class="col_heading level0 col1" >E</th>
#       <th id="T_8e570_level0_col2" class="col_heading level0 col2" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e570_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_8e570_row0_col0" class="data row0 col0" >d3</td>
#       <td id="T_8e570_row0_col1" class="data row0 col1" >e3</td>
#       <td id="T_8e570_row0_col2" class="data row0 col2" >f3</td>
#     </tr>
#     <tr>
#       <th id="T_8e570_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_8e570_row1_col0" class="data row1 col0" >d4</td>
#       <td id="T_8e570_row1_col1" class="data row1 col1" >e4</td>
#       <td id="T_8e570_row1_col2" class="data row1 col2" >f4</td>
#     </tr>
#     <tr>
#       <th id="T_8e570_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_8e570_row2_col0" class="data row2 col0" >d5</td>
#       <td id="T_8e570_row2_col1" class="data row2 col1" >e5</td>
#       <td id="T_8e570_row2_col2" class="data row2 col2" >f5</td>
#     </tr>
#   </tbody>
# </table>
#     A   B   C   D   E   F
# 0  a0  b0  c0  d0  e0  f0
# 1  a1  b1  c1  d1  e1  f1
# 2  a2  b2  c2  d2  e2  f2
# 3  a3  b3  c3  d3  e3  f3
# 4  a4  b4  c4  d4  e4  f4
# 5  a5  b5  c5  d5  e5  f5
